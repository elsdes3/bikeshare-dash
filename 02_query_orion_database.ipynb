# %% [markdown]
# # Querying Prefect Orion Database

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
import os
from typing import Union

import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ## About

# %% [markdown]
# Examining the Prefect Orion database for flow and task runs.

# %% [markdown]
# ## User Inputs

# %%
db_filepath = f"sqlite:///{os.path.expanduser('~')}/.prefect/orion.db"

# %%
def show_sql_df(
    query: str,
    conn,
    show_output: bool = True,
    max_cols: Union[int, None] = 100,
    max_colwidth: Union[int, None] = None,
) -> Union[None, pd.DataFrame]:
    """Fetch and display results of SQL query."""
    try:
        df_query_output = pd.read_sql(query, con=conn)
        print(f"Got {len(df_query_output):,} rows of results")
        if not df_query_output.empty:
            if show_output:
                with pd.option_context(
                    "display.max_columns",
                    max_cols,
                    "display.max_colwidth",
                    max_colwidth,
                ):
                    display(df_query_output)
            return df_query_output
    except Exception as e:
        print(str(e))
    return None

# %%
# Connect to all databases (required to perform CRUD operations and submit queries)
# URI = f"{DB_TYPE}+{DB_DRIVER}://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
URI = db_filepath

# %%
engine = create_engine(URI)
conn = engine.connect()

# %% [markdown]
# ## Run Queries

# %% [markdown]
# ### Show All Tables in Database

# %%
# %%time
query = """
        SELECT name
        FROM sqlite_master
        WHERE type='table'
        """
_ = show_sql_df(query, conn)

# %% [markdown]
# ### Show Five Most Recent Completed Flow Runs Filtered by Flow Parameters

# %%
# %%time
query = """
        SELECT *
        FROM (
            SELECT *
            FROM flow_run
            WHERE state_type = 'COMPLETED'
            AND json_array_length(json_extract(parameters, '$.nrows')) > 5
            ORDER BY start_time DESC
            LIMIT 5
        )
        ORDER BY start_time
        """
_ = show_sql_df(query, conn)

# %% [markdown]
# ### Show All Completed Flow Runs, Filtered by Flow Parameters, and their Corresponding Task Runs and Task Run States

# %%
# %%time
query = """
        /* FLOW RUNS */
        WITH single_flow_run AS (
            SELECT flow_id,
                   id AS flow_run_id,
                   deployment_id,
                   name AS flow_run_name,
                   start_time AS flow_run_start_time,
                   end_time AS flow_run_end_time,
                   flow_version,
                   parameters AS flow_parameters,
                   flow_runner_type
            FROM flow_run
            -- select flow_run_id that is one of the IDs from the five
            -- flow runs found above
            WHERE flow_run_id = '2fa0f339-76b5-4dbe-a021-9b22ae73f4a6'
            AND state_type = 'COMPLETED'
        ),
        /* TASK RUNS */
        task_runs_for_single_flow_run AS (
            SELECT id AS task_run_id,
                   name AS task_run_name,
                   tags AS task_run_tags,
                   run_count AS task_run_count,
                   start_time AS task_run_start_time,
                   end_time AS task_run_end_time,
                   task_key,
                   task_version,
                   flow_run_id
            FROM task_run
            WHERE flow_run_id = '2fa0f339-76b5-4dbe-a021-9b22ae73f4a6'
            AND state_type = 'COMPLETED'
            ORDER BY task_run_start_time
        ),
        /* TASK RUN STATES */
        task_run_states AS (
            SELECT id AS task_run_state_id,
                   created AS task_run_state_created,
                   updated AS task_run_state_updated,
                   type AS task_run_state_type,
                   timestamp AS task_run_state_timestamp,
                   name AS task_run_state_name,
                   json_extract(data, '$.encoding') AS task_run_state_data_encoding,
                   json_extract(data, '$.blob') AS task_run_state_data_blob,
                   task_run_id
            FROM task_run_state
            WHERE data != 'null'
        ),
        /* SUMMARY VIEW */
        flow_summary AS (
            SELECT flow_run_id,
                   flow_run_name,
                   flow_id,
                   flow_name,
                   flow_tags,
                   flow_version,
                   flow_parameters,
                   flow_runner_type,
                   deployment_id,
                   flow_run_start_time,
                   task_run_id,
                   task_run_name,
                   task_run_tags,
                   task_run_count,
                   task_run_start_time,
                   task_run_end_time,
                   flow_run_end_time,
                   task_key,
                   task_version,
                   task_run_state_id,
                   task_run_state_created,
                   task_run_state_updated,
                   task_run_state_type,
                   task_run_state_timestamp,
                   task_run_state_name,
                   task_run_state_data_encoding,
                   task_run_state_data_blob
            FROM single_flow_run
            LEFT JOIN task_runs_for_single_flow_run USING (flow_run_id)
            LEFT JOIN (
                SELECT id AS flow_id,
                       name AS flow_name,
                       tags AS flow_tags
                FROM flow
            ) AS f USING (flow_id)
            LEFT JOIN task_run_states USING (task_run_id)
            ORDER BY flow_run_start_time, task_run_start_time
        )
        SELECT *
        FROM flow_summary
        """
_ = show_sql_df(query, conn, max_colwidth=50)
# Out:
# Got 18 rows of results
#                              flow_run_id      flow_run_name  \
# 0   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 1   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 2   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 3   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 4   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 5   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 6   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 7   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 8   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 9   2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 10  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 11  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 12  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 13  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 14  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 15  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 16  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
# 17  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6  rational-mushroom
#
#                                  flow_id        flow_name flow_tags  \
# 0   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 1   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 2   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 3   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 4   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 5   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 6   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 7   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 8   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 9   dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 10  dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 11  dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 12  dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 13  dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 14  dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 15  dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 16  dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
# 17  dbbbb6ed-a38c-4f91-929b-76e0fb040a00  My Example Flow        []
#
#    flow_version                                    flow_parameters  \
# 0   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 1   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 2   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 3   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 4   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 5   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 6   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 7   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 8   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 9   tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 10  tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 11  tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 12  tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 13  tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 14  tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 15  tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 16  tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
# 17  tutorial_02  {"nrows": [17, 25, 38, 55, 1105, 170], "load_s...
#
#    flow_runner_type deployment_id         flow_run_start_time  \
# 0              None          None  2022-04-28 19:54:49.308070
# 1              None          None  2022-04-28 19:54:49.308070
# 2              None          None  2022-04-28 19:54:49.308070
# 3              None          None  2022-04-28 19:54:49.308070
# 4              None          None  2022-04-28 19:54:49.308070
# 2   2022-04-28 19:54:49.552710           Completed
# 3   2022-04-28 19:54:49.628163           Completed
# 4   2022-04-28 19:54:49.706491           Completed
# 5   2022-04-28 19:54:49.782730           Completed
# 6   2022-04-28 19:54:49.858797           Completed
# 7   2022-04-28 19:54:49.937630           Completed
# 8   2022-04-28 19:54:50.082723           Completed
# 9   2022-04-28 19:54:50.161866           Completed
# 10  2022-04-28 19:54:50.244027           Completed
# 11  2022-04-28 19:54:50.324501           Completed
# 12  2022-04-28 19:54:50.399244           Completed
# 13  2022-04-28 19:54:50.480206           Completed
# 14  2022-04-28 19:54:50.566946           Completed
# 15  2022-04-28 19:54:50.644047           Completed
# 16  2022-04-28 19:54:50.726284           Completed
# 17  2022-04-28 19:54:50.804333           Completed
#
#    task_run_state_data_encoding  \
# 0                   cloudpickle
# 1                   cloudpickle
# 2                   cloudpickle
# 3                   cloudpickle
# 4                   cloudpickle
# 5                   cloudpickle
# 6                   cloudpickle
# 7                   cloudpickle
# 8                   cloudpickle
# 9                   cloudpickle
# 10                  cloudpickle
# 11                  cloudpickle
# 12                  cloudpickle
# 13                  cloudpickle
# 14                  cloudpickle
# 15                  cloudpickle
# 16                  cloudpickle
# 17                  cloudpickle
#
#                              task_run_state_data_blob
# 0   gAWVWwUAAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 1   gAWVWwUAAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 2                                          gAVOLg==\n
# 3   gAWVmwYAAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 4   gAWVmwYAAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 5                                          gAVOLg==\n
# 6   gAWVowgAAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 7   gAWVowgAAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 8                                          gAVOLg==\n
# 9   gAWVSwsAAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 10  gAWVSwsAAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 11                                         gAVOLg==\n
# 12  gAWVXa8AAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 13  gAWVXa8AAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 14                                         gAVOLg==\n
# 15  gAWVQx0AAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 16  gAWVQx0AAAAAAACMEXBhbmRhcy5jb3JlLmZyYW1llIwJRG...
# 17                                         gAVOLg==\n
# CPU times: user 23.7 ms, sys: 1.98 ms, total: 25.7 ms
# Wall time: 23.2 ms

# %% [markdown]
# ### Note About Showing Deployment Flow Runs Without Work Queues

# %% [markdown]
# When a deployment is created it can be shown, along with its corresponding `flow_id`, in the `deployment` table as seen below

# %%
# %%time
query = """
        SELECT *
        FROM deployment
        """
_ = show_sql_df(query, conn)
# Out:
# Got 1 rows of results
#                                      id                     created  \
# 0  b1560641-974a-4519-a4a9-4a0453a7dae8  2022-04-28 19:09:35.775481
#
#                       updated             name schedule  is_schedule_active  \
# 0  2022-04-28 19:09:35.771330  demo-deployment     null                   1
#
#                           tags  \
# 0  ["tutorial", "test-deploy"]
#
#                                                         parameters  \
# 0  {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
#
#                                                                                                                                                                                      flow_data  \
# 0  {"encoding": "blockstorage", "blob": "{\"data\": \"\\\"/home/elsdes3/.prefect/storage/c5ffa862-1bcf-4b64-b716-019a5269e93f\\\"\", \"block_id\": \"a753fe1f-f18e-42d6-9c6b-10654687968b\"}"}
#
#   flow_runner_type  \
# 0       subprocess
#
#                                                          flow_runner_config  \
# 0  {"env": {}, "stream_output": true, "condaenv": null, "virtualenv": null}
#
#                                 flow_id
# 0  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# CPU times: user 10.6 ms, sys: 0 ns, total: 10.6 ms
# Wall time: 9.23 ms

# %% [markdown]
# **(NEEDS TO BE VERIFIED)** It does not appear that this approach of running a flow registers as a flow run in the `flow_run` table in the Orion database in the same way that a non-deployment flow run would. This can be seen below where the `flow_id` associated with the deployment shown above does not appear in the `flow run` table even though the Prefect CLI was used to execute a local flow run for this deployment [per the Prefect Orion tutorial docs](https://orion-docs.prefect.io/tutorials/deployments/#creating-the-deployment). For such a locally executed flow run, the `deployment_id` column should contain the ID of the deployment shown in the `deployment` table earlier, but this column only contains missing values

# %%
# %%time
query = """
        SELECT id,
               flow_id,
               parameters,
               deployment_id
        FROM flow_run
        WHERE flow_id = 'dbbbb6ed-a38c-4f91-929b-76e0fb040a00'
        """
_ = show_sql_df(query, conn)
# Out:
# Got 19 rows of results
#                                       id  \
# 0   241a4959-7701-41a2-b024-42944fc89dab
# 1   122f94f0-68ca-43c8-94c6-82ec02cd73cc
# 2   2d7fe59f-688f-4a12-af37-6651a21b505c
# 3   4992bd2b-2f9f-41f2-b20c-3a8c364d8c38
# 4   af502ba6-3a95-42f6-818c-ce61ccb608da
# 5   713c181c-0da5-4e5f-a1fa-d200afa89d38
# 6   69b42ef3-b836-460c-be7a-8be0c70f002a
# 7   7140ee17-4353-49cd-ad16-2c72b35d08d1
# 8   57485528-d2e2-4c2a-be39-563c34536125
# 9   76f1bb0c-373f-4bfa-af87-aae6a8c514ac
# 10  eadb3e16-e83f-40e3-9578-4bed86f8822e
# 11  6b764200-fd90-4b30-83ff-53a984203762
# 12  46bbe355-0bb4-4be0-98f1-369723ad39bc
# 13  7de2f75c-f430-403c-ba57-85debe11ecb0
# 14  2707f576-f11b-408d-9792-8ff735a01008
# 15  8171cbed-aeae-4cae-9a69-e502b88396c3
# 16  2fa0f339-76b5-4dbe-a021-9b22ae73f4a6
# 17  2e3f0e69-5ea9-4929-9345-443310d4d2a8
# 18  8c405aa7-5122-4fff-82c6-ba57d71829bd
#
#                                  flow_id  \
# 0   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 1   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 2   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 3   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 4   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 5   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 6   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 7   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 8   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 9   dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 10  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 11  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 12  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 13  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 14  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 15  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 16  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 17  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
# 18  dbbbb6ed-a38c-4f91-929b-76e0fb040a00
#
#                                                          parameters  \
# 0                            {"nrows": 12, "load_str": "db-loader"}
# 1                      {"nrows": [12, 15], "load_str": "db-loader"}
# 2                      {"nrows": [12, 15], "load_str": "db-loader"}
# 3                      {"nrows": [12, 15], "load_str": "db-loader"}
# 4                      {"nrows": [12, 15], "load_str": "db-loader"}
# 5   {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
# 6   {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
# 7   {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
# 8   {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
# 9   {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
# 10  {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
# 11                         {"nrows": [17], "load_str": "db-loader"}
# 12                         {"nrows": [17], "load_str": "db-loader"}
# 13                         {"nrows": [17], "load_str": "db-loader"}
# 14                         {"nrows": [25], "load_str": "db-loader"}
# 15                         {"nrows": [25], "load_str": "db-loader"}
# 16  {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
# 17  {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
# 18  {"nrows": [17, 25, 38, 55, 1105, 170], "load_str": "db-loader"}
#
#    deployment_id
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# 5           None
# 6           None
# 7           None
# 8           None
# 9           None
# 10          None
# 11          None
# 12          None
# 13          None
# 14          None
# 15          None
# 16          None
# 17          None
# 18          None
# CPU times: user 6.45 ms, sys: 1.52 ms, total: 7.97 ms
# Wall time: 6.32 ms

# %%
conn.close()
engine.dispose()

# %% [markdown]
# ## Links

# %% [markdown]
# 1. (Not done here) [**Changing to PostgreSQL database**](https://orion-docs.prefect.io/concepts/database/#configuring-a-postgresql-database)
#    - full setup instructions using Docker container
